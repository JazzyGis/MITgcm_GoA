# %% [markdown]
# <a href="https://colab.research.google.com/github/JazzyGis/MITgcm_GoA/blob/main/extended_dpCO2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/JazzyGis/MITgcm_GoA.git
# Out:
# fatal: destination path 'MITgcm_GoA' already exists and is not an empty directory.

# %%
import sys
sys.path.append('/content/MITgcm_GoA.git/figures/pco2_mooring_analysis.ipynb')

# %%
pip install importnb

# %%
#from importnb import Notebook
#with Notebook():
 #   import pco2_mooring_analysis

# %%
# %run pco2_mooring_analysis.ipynb
# Out:
# ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /content/pco2_mooring_analysis.ipynb in <cell line: 0>()
# ----> 1 df = pd.read_csv('OSP_2008_to_2025.csv')
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
# ...

# %%
sss = ds_daily['Salinity'].to_numpy()
#rerun pyco2
results1 = pyco2.sys(par1 = ds_daily['xCO2 SW (dry) (umolPermol)'], par1_type = 9,
                    par2 = ds_daily['pH (total scale)'], par2_type = 3,
                    salinity=ds_daily['Salinity']+1,
                    temperature=ds_daily['SST (C)'])
dpCO2S = results1['pCO2'] - results['pCO2']
